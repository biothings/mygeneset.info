# %% [markdown]
# # Use MyGeneset.info API in analytic workflows

# %% [markdown]
# The code example below illustrates the use of [MyGeneset.info API](https://mygeneset.info) for simplifying functional gene set analytical workflows. Users can search for gene sets by keywords (e.g. “impaired glucose tolerance”) and retrieve basic information about the gene set including the name, the NCBI taxon ID of the gene set, common identifiers of gene members etc. The expanded gene-level annotations can be further obtained from the companion [MyGene.info API](https://mygene.info).

# %% [markdown]
# The example code below uses popular [requests](https://requests.readthedocs.io) package to make API calls. `requests` can be easily installed as:
#
# ```bash
# pip install requests
# ```

# %%
## import necessary packages first
from pprint import pprint
import requests

# %%
## Fetch gene sets involved in “impaired glucose tolerance”, include the taxon id of the gene set itself as well as the name, Uniprot ID, and mygene.info identifier for each gene in the gene set.
r = requests.get('https://mygeneset.info/v1/query/?q="impaired glucose tolerance"&fields=taxid,genes.name,genes.uniprot,genes.mygene_id')
data = r.json()
pprint(data)
# Out:
# {'hits': [{'_id': 'HP_IMPAIRED_GLUCOSE_TOLERANCE',
#            '_score': 38.72672,
#            'genes': [{'mygene_id': '10219',
#                       'name': 'killer cell lectin like receptor G1',
#                       'uniprot': 'Q96E93'},
#                      {'mygene_id': '389692',
#                       'name': 'MAF bZIP transcription factor A',
#                       'uniprot': 'Q8NHW3'},
#                      {'mygene_id': '7466',
#                       'name': 'wolframin ER transmembrane glycoprotein',
#                       'uniprot': 'O76024'},
#                      {'mygene_id': '286053',
#                       'name': 'NSE2 (MMS21) homolog, SMC5-SMC6 complex SUMO '
#                               'ligase',
#                       'uniprot': 'Q96MF7'},
#                      {'mygene_id': '3643',
#                       'name': 'insulin receptor',
#                       'uniprot': 'P06213'},
#                      {'mygene_id': '8462',
#                       'name': 'KLF transcription factor 11',
#                       'uniprot': 'O14901'},
#                      {'mygene_id': '6523',
#                       'name': 'solute carrier family 5 member 1',
#                       'uniprot': 'P13866'},
#                      {'mygene_id': '857',
#                       'name': 'caveolin 1',
#                       'uniprot': 'Q03135'},
#                      {'mygene_id': '5871',
#                       'name': 'mitogen-activated protein kinase kinase kinase '
#                               'kinase 2',
#                       'uniprot': 'Q12851'},
#                      {'mygene_id': '2645',
#                       'name': 'glucokinase',
#                       'uniprot': 'P35557'},
#                      {'mygene_id': '640',
#                       'name': 'BLK proto-oncogene, Src family tyrosine kinase',
#                       'uniprot': 'P51451'},
#                      {'mygene_id': '3767',
#                       'name': 'potassium inwardly rectifying channel subfamily '
#                               'J member 11',
#                       'uniprot': 'Q14654'},
#                      {'mygene_id': '4760',
#                       'name': 'neuronal differentiation 1',
#                       'uniprot': 'Q13562'},
#                      {'mygene_id': '64072',
#                       'name': 'cadherin related 23',
#                       'uniprot': 'Q9H251'},
#                      {'mygene_id': '26060',
#                       'name': 'adaptor protein, phosphotyrosine interacting '
#                               'with PH domain and leucine zipper 1',
#                       'uniprot': 'Q9UKG1'},
#                      {'mygene_id': '8050',
#                       'name': 'pyruvate dehydrogenase complex component X',
#                       'uniprot': 'O00330'},
#                      {'mygene_id': '3651',
#                       'name': 'pancreatic and duodenal homeobox 1',
#                       'uniprot': 'P52945'},
#                      {'mygene_id': '6833',
#                       'name': 'ATP binding cassette subfamily C member 8',
#                       'uniprot': 'Q09428'},
#                      {'mygene_id': '6927',
#                       'name': 'HNF1 homeobox A',
#                       'uniprot': 'P20823'},
#                      {'mygene_id': '3630',
#                       'name': 'insulin',
#                       'uniprot': 'P01308'},
#                      {'mygene_id': '9101',
#                       'name': 'ubiquitin specific peptidase 8',
#                       'uniprot': 'P40818'},
#                      {'mygene_id': '6928',
#                       'name': 'HNF1 homeobox B',
#                       'uniprot': 'P35680'},
#                      {'mygene_id': '4040',
#                       'name': 'LDL receptor related protein 6',
#                       'uniprot': 'O75581'},
#                      {'mygene_id': '6514',
#                       'name': 'solute carrier family 2 member 2',
#                       'uniprot': 'P11168'},
#                      {'mygene_id': '26160',
#                       'name': 'intraflagellar transport 172',
#                       'uniprot': 'Q9UG01'},
#                      {'mygene_id': '30061',
#                       'name': 'solute carrier family 40 member 1',
#                       'uniprot': 'Q9NP59'},
#                      {'mygene_id': '3172',
#                       'name': 'hepatocyte nuclear factor 4 alpha',
#                       'uniprot': 'P41235'},
#                      {'mygene_id': '4000',
#                       'name': 'lamin A/C',
#                       'uniprot': 'P02545'},
#                      {'mygene_id': '5078',
#                       'name': 'paired box 4',
#                       'uniprot': 'O43316'},
#                      {'mygene_id': '11232',
#                       'name': 'DNA polymerase gamma 2, accessory subunit',
#                       'uniprot': 'Q9UHN1'},
#                      {'mygene_id': '2099',
#                       'name': 'estrogen receptor 1',
#                       'uniprot': 'P03372'},
#                      {'mygene_id': '1056', 'name': 'carboxyl ester lipase'},
#                      {'mygene_id': '5696',
#                       'name': 'proteasome 20S subunit beta 8',
#                       'uniprot': 'P28062'},
#                      {'mygene_id': '54998',
#                       'name': 'aurora kinase A interacting protein 1',
#                       'uniprot': 'Q9NWT8'},
#                      {'mygene_id': '9049',
#                       'name': 'aryl hydrocarbon receptor interacting protein',
#                       'uniprot': 'O00170'}],
#            'taxid': 9606},
#           {'_id': 'HP_GLUCOSE_INTOLERANCE',
#            '_score': 30.0252,
#            'genes': [{'mygene_id': '7157',
#                       'name': 'tumor protein p53',
#                       'uniprot': 'P04637'},
#                      {'mygene_id': '81555',
#                       'name': 'Yip1 domain family member 5',
#                       'uniprot': 'Q969M3'},
#                      {'mygene_id': '8842',
#                       'name': 'prominin 1',
#                       'uniprot': 'O43490'},
#                      {'mygene_id': '1736',
#                       'name': 'dyskerin pseudouridine synthase 1',
#                       'uniprot': 'O60832'},
#                      {'mygene_id': '8462',
#                       'name': 'KLF transcription factor 11',
#                       'uniprot': 'O14901'},
#                      {'mygene_id': '5078',
#                       'name': 'paired box 4',
#                       'uniprot': 'O43316'},
#                      {'mygene_id': '8050',
#                       'name': 'pyruvate dehydrogenase complex component X',
#                       'uniprot': 'O00330'},
#                      {'mygene_id': '3651',
#                       'name': 'pancreatic and duodenal homeobox 1',
#                       'uniprot': 'P52945'},
#                      {'mygene_id': '9968',
#                       'name': 'mediator complex subunit 12',
#                       'uniprot': 'Q93074'},
#                      {'mygene_id': '4976',
#                       'name': 'OPA1 mitochondrial dynamin like GTPase',
#                       'uniprot': 'O60313'},
#                      {'mygene_id': '4556', 'name': 'tRNA-Glu'},
#                      {'mygene_id': '3159',
#                       'name': 'high mobility group AT-hook 1',
#                       'uniprot': 'P17096'},
#                      {'mygene_id': '79140',
#                       'name': 'coiled-coil domain containing 28B',
#                       'uniprot': 'Q9BUN5'},
#                      {'mygene_id': '8788',
#                       'name': 'delta like non-canonical Notch ligand 1',
#                       'uniprot': 'P80370'},
#                      {'mygene_id': '4692',
#                       'name': 'necdin, MAGE family member',
#                       'uniprot': 'Q99608'},
#                      {'mygene_id': '10273',
#                       'name': 'STIP1 homology and U-box containing protein 1',
#                       'uniprot': 'Q9UNE7'},
#                      {'mygene_id': '2627',
#                       'name': 'GATA binding protein 6',
#                       'uniprot': 'Q92908'},
#                      {'mygene_id': '10059',
#                       'name': 'dynamin 1 like',
#                       'uniprot': 'O00429'},
#                      {'mygene_id': '54741',
#                       'name': 'leptin receptor overlapping transcript',
#                       'uniprot': 'O15243'},
#                      {'mygene_id': '3953',
#                       'name': 'leptin receptor',
#                       'uniprot': 'P48357'},
#                      {'mygene_id': '55857',
#                       'name': 'kizuna centrosomal protein',
#                       'uniprot': 'Q2M2Z5'},
#                      {'mygene_id': '3043',
#                       'name': 'hemoglobin subunit beta',
#                       'uniprot': 'P68871'},
#                      {'mygene_id': '85344', 'name': 'keratin 89, pseudogene'},
#                      {'mygene_id': '3630',
#                       'name': 'insulin',
#                       'uniprot': 'P01308'},
#                      {'mygene_id': '2625',
#                       'name': 'GATA binding protein 3',
#                       'uniprot': 'P23771'},
#                      {'mygene_id': '4723',
#                       'name': 'NADH:ubiquinone oxidoreductase core subunit V1',
#                       'uniprot': 'P49821'},
#                      {'mygene_id': '4540',
#                       'name': 'NADH dehydrogenase subunit 5',
#                       'uniprot': 'P03915'},
#                      {'mygene_id': '2395',
#                       'name': 'frataxin',
#                       'uniprot': 'Q16595'},
#                      {'mygene_id': '2969',
#                       'name': 'general transcription factor IIi',
#                       'uniprot': 'P78347'},
#                      {'mygene_id': '100093631',
#                       'name': 'general transcription factor IIi pseudogene 4'},
#                      {'mygene_id': '4751',
#                       'name': 'NIMA related kinase 2',
#                       'uniprot': 'P51955'},
#                      {'mygene_id': '6638',
#                       'name': 'small nuclear ribonucleoprotein polypeptide N',
#                       'uniprot': 'P63162'},
#                      {'mygene_id': '1356',
#                       'name': 'ceruloplasmin',
#                       'uniprot': 'P00450'},
#                      {'mygene_id': '653361',
#                       'name': 'neutrophil cytosolic factor 1',
#                       'uniprot': 'P14598'},
#                      {'mygene_id': '8622',
#                       'name': 'phosphodiesterase 8B',
#                       'uniprot': 'O95263'},
#                      {'mygene_id': '4537',
#                       'name': 'NADH dehydrogenase subunit 3',
#                       'uniprot': 'P03897'},
#                      {'mygene_id': '80067',
#                       'name': 'DDB1 and CUL4 associated factor 17',
#                       'uniprot': 'Q5H9S7'},
#                      {'mygene_id': '4760',
#                       'name': 'neuronal differentiation 1',
#                       'uniprot': 'Q13562'},
#                      {'mygene_id': '7458',
#                       'name': 'eukaryotic translation initiation factor 4H',
#                       'uniprot': 'Q15056'},
#                      {'mygene_id': '6934',
#                       'name': 'transcription factor 7 like 2',
#                       'uniprot': 'Q9NQB0'},
#                      {'mygene_id': '6925',
#                       'name': 'transcription factor 4',
#                       'uniprot': 'P15884'},
#                      {'mygene_id': '6514',
#                       'name': 'solute carrier family 2 member 2',
#                       'uniprot': 'P11168'},
#                      {'mygene_id': '10269',
#                       'name': 'zinc metallopeptidase STE24',
#                       'uniprot': 'O75844'},
#                      {'mygene_id': '7466',
#                       'name': 'wolframin ER transmembrane glycoprotein',
#                       'uniprot': 'O76024'},
#                      {'mygene_id': '6928',
#                       'name': 'HNF1 homeobox B',
#                       'uniprot': 'P35680'},
#                      {'mygene_id': '54998',
#                       'name': 'aurora kinase A interacting protein 1',
#                       'uniprot': 'Q9NWT8'},
#                      {'mygene_id': '9049',
#                       'name': 'aryl hydrocarbon receptor interacting protein',
#                       'uniprot': 'O00170'},
#                      {'mygene_id': '3514',
#                       'name': 'immunoglobulin kappa constant'},
#                      {'mygene_id': '3617',
#                       'name': 'interphotoreceptor matrix proteoglycan 1',
#                       'uniprot': 'Q17R60'},
#                      {'mygene_id': '5871',
#                       'name': 'mitogen-activated protein kinase kinase kinase '
#                               'kinase 2',
#                       'uniprot': 'Q12851'},
#                      {'mygene_id': '2645',
#                       'name': 'glucokinase',
#                       'uniprot': 'P35557'},
#                      {'mygene_id': '56652',
#                       'name': 'twinkle mtDNA helicase',
#                       'uniprot': 'Q96RR1'},
#                      {'mygene_id': '4564', 'name': 'tRNA-His'},
#                      {'mygene_id': '4838',
#                       'name': 'nodal growth differentiation factor',
#                       'uniprot': 'Q96S42'},
#                      {'mygene_id': '4726',
#                       'name': 'NADH:ubiquinone oxidoreductase subunit S6',
#                       'uniprot': 'O75380'},
#                      {'mygene_id': '7518',
#                       'name': 'X-ray repair cross complementing 4',
#                       'uniprot': 'Q13426'},
#                      {'mygene_id': '80169',
#                       'name': 'CST telomere replication complex component 1',
#                       'uniprot': 'Q2NKJ3'},
#                      {'mygene_id': '9101',
#                       'name': 'ubiquitin specific peptidase 8',
#                       'uniprot': 'P40818'},
#                      {'mygene_id': '4524',
#                       'name': 'methylenetetrahydrofolate reductase',
#                       'uniprot': 'P42898'},
#                      {'mygene_id': '4512',
#                       'name': 'cytochrome c oxidase subunit I',
#                       'uniprot': 'P00395'},
#                      {'mygene_id': '55315',
#                       'name': 'solute carrier family 29 member 3',
#                       'uniprot': 'Q9BZD2'},
#                      {'mygene_id': '51103',
#                       'name': 'NADH:ubiquinone oxidoreductase complex assembly '
#                               'factor 1',
#                       'uniprot': 'Q9Y375'},
#                      {'mygene_id': '55624',
#                       'name': 'protein O-linked mannose '
#                               'N-acetylglucosaminyltransferase 1 (beta 1,2-)',
#                       'uniprot': 'Q8WZA1'},
#                      {'mygene_id': '4040',
#                       'name': 'LDL receptor related protein 6',
#                       'uniprot': 'O75581'},
#                      {'mygene_id': '6772',
#                       'name': 'signal transducer and activator of '
#                               'transcription 1',
#                       'uniprot': 'P42224'},
#                      {'mygene_id': '60675',
#                       'name': 'prokineticin 2',
#                       'uniprot': 'Q9HC23'},
#                      {'mygene_id': '4535',
#                       'name': 'NADH dehydrogenase subunit 1',
#                       'uniprot': 'P03886'},
#                      {'mygene_id': '9227',
#                       'name': 'lecithin retinol acyltransferase',
#                       'uniprot': 'O95237'},
#                      {'mygene_id': '1188',
#                       'name': 'chloride voltage-gated channel Kb',
#                       'uniprot': 'P51801'},
#                      {'mygene_id': '125316803',
#                       'name': 'POLG alternative reading frame'},
#                      {'mygene_id': '5428',
#                       'name': 'DNA polymerase gamma, catalytic subunit',
#                       'uniprot': 'P54098'},
#                      {'mygene_id': '8820',
#                       'name': 'HESX homeobox 1',
#                       'uniprot': 'Q9UBX0'},
#                      {'mygene_id': '57709',
#                       'name': 'solute carrier family 7 member 14',
#                       'uniprot': 'Q8TBB6'},
#                      {'mygene_id': '25915',
#                       'name': 'NADH:ubiquinone oxidoreductase complex assembly '
#                               'factor 3',
#                       'uniprot': 'Q9BU61'},
#                      {'mygene_id': '84153',
#                       'name': 'ribonuclease H2 subunit C',
#                       'uniprot': 'Q8TDP1'},
#                      {'mygene_id': '388939',
#                       'name': 'photoreceptor cilium actin regulator',
#                       'uniprot': 'A6NGG8'},
#                      {'mygene_id': '4719',
#                       'name': 'NADH:ubiquinone oxidoreductase core subunit S1',
#                       'uniprot': 'P28331'},
#                      {'mygene_id': '2531',
#                       'name': '3-ketodihydrosphingosine reductase',
#                       'uniprot': 'Q06136'},
#                      {'mygene_id': '5325',
#                       'name': 'PLAG1 like zinc finger 1',
#                       'uniprot': 'Q9UM63'},
#                      {'mygene_id': '64135',
#                       'name': 'interferon induced with helicase C domain 1',
#                       'uniprot': 'Q9BYX4'},
#                      {'mygene_id': '92840',
#                       'name': 'receptor accessory protein 6',
#                       'uniprot': 'Q96HR9'},
#                      {'mygene_id': '284119',
#                       'name': 'caveolae associated protein 1',
#                       'uniprot': 'Q6NZI2'},
#                      {'mygene_id': '10908',
#                       'name': 'patatin like phospholipase domain containing 6',
#                       'uniprot': 'Q8IY17'},
#                      {'mygene_id': '57061',
#                       'name': 'hydatidiform mole associated and imprinted'},
#                      {'mygene_id': '6523',
#                       'name': 'solute carrier family 5 member 1',
#                       'uniprot': 'P13866'},
#                      {'mygene_id': '138050',
#                       'name': 'heparan-alpha-glucosaminide N-acetyltransferase',
#                       'uniprot': 'Q68CP4'},
#                      {'mygene_id': '857',
#                       'name': 'caveolin 1',
#                       'uniprot': 'Q03135'},
#                      {'mygene_id': '55384', 'name': 'maternally expressed 3'},
#                      {'mygene_id': '64072',
#                       'name': 'cadherin related 23',
#                       'uniprot': 'Q9H251'},
#                      {'mygene_id': '4728',
#                       'name': 'NADH:ubiquinone oxidoreductase core subunit S8',
#                       'uniprot': 'O00217'},
#                      {'mygene_id': '1499',
#                       'name': 'catenin beta 1',
#                       'uniprot': 'P35222'},
#                      {'mygene_id': '3952',
#                       'name': 'leptin',
#                       'uniprot': 'P41159'},
#                      {'mygene_id': '10108', 'name': 'MKRN3 antisense RNA 1'},
#                      {'mygene_id': '24',
#                       'name': 'ATP binding cassette subfamily A member 4',
#                       'uniprot': 'P78363'},
#                      {'mygene_id': '9275',
#                       'name': 'BAF chromatin remodeling complex subunit BCL7B',
#                       'uniprot': 'Q9BQE9'},
#                      {'mygene_id': '4574', 'name': 'tRNA-Ser'},
#                      {'mygene_id': '4558', 'name': 'tRNA-Phe'},
#                      {'mygene_id': '256297',
#                       'name': 'pancreas associated transcription factor 1a',
#                       'uniprot': 'Q7RTS3'},
#                      {'mygene_id': '2260',
#                       'name': 'fibroblast growth factor receptor 1',
#                       'uniprot': 'P11362'},
#                      {'mygene_id': '5727',
#                       'name': 'patched 1',
#                       'uniprot': 'Q13635'},
#                      {'mygene_id': '4693',
#                       'name': 'norrin cystine knot growth factor NDP',
#                       'uniprot': 'Q00604'},
#                      {'mygene_id': '3559',
#                       'name': 'interleukin 2 receptor subunit alpha',
#                       'uniprot': 'P01589'},
#                      {'mygene_id': '136541',
#                       'name': 'serine protease 58',
#                       'uniprot': 'Q8IYP2'},
#                      {'mygene_id': '5644',
#                       'name': 'serine protease 1',
#                       'uniprot': 'P07477'},
#                      {'mygene_id': '4854',
#                       'name': 'notch receptor 3',
#                       'uniprot': 'Q9UM47'},
#                      {'mygene_id': '4720',
#                       'name': 'NADH:ubiquinone oxidoreductase core subunit S2',
#                       'uniprot': 'O75306'},
#                      {'mygene_id': '4541',
#                       'name': 'NADH dehydrogenase subunit 6',
#                       'uniprot': 'P03923'},
#                      {'mygene_id': '23600',
#                       'name': 'alpha-methylacyl-CoA racemase',
#                       'uniprot': 'Q9UHK6'},
#                      {'mygene_id': '6927',
#                       'name': 'HNF1 homeobox A',
#                       'uniprot': 'P20823'},
#                      {'mygene_id': '3172',
#                       'name': 'hepatocyte nuclear factor 4 alpha',
#                       'uniprot': 'P41235'},
#                      {'mygene_id': '7840',
#                       'name': 'ALMS1 centrosome and basal body associated '
#                               'protein',
#                       'uniprot': 'Q8TCU4'},
#                      {'mygene_id': '7681',
#                       'name': 'makorin ring finger protein 3',
#                       'uniprot': 'Q13064'},
#                      {'mygene_id': '6496',
#                       'name': 'SIX homeobox 3',
#                       'uniprot': 'O95343'},
#                      {'mygene_id': '51750',
#                       'name': 'regulator of telomere elongation helicase 1',
#                       'uniprot': 'Q9NZ71'},
#                      {'mygene_id': '4716',
#                       'name': 'NADH:ubiquinone oxidoreductase subunit B10',
#                       'uniprot': 'O96000'},
#                      {'mygene_id': '55812',
#                       'name': 'spermatogenesis associated 7',
#                       'uniprot': 'Q9P0W8'},
#                      {'mygene_id': '50937',
#                       'name': 'cell adhesion associated, oncogene regulated',
#                       'uniprot': 'Q4KMG0'},
#                      {'mygene_id': '5578',
#                       'name': 'protein kinase C alpha',
#                       'uniprot': 'P17252'},
#                      {'mygene_id': '5566',
#                       'name': 'protein kinase cAMP-activated catalytic subunit '
#                               'alpha',
#                       'uniprot': 'P17612'},
#                      {'mygene_id': '3710',
#                       'name': 'inositol 1,4,5-trisphosphate receptor type 3',
#                       'uniprot': 'Q14573'},
#                      {'mygene_id': '291',
#                       'name': 'solute carrier family 25 member 4',
#                       'uniprot': 'P12235'},
#                      {'mygene_id': '5424',
#                       'name': 'DNA polymerase delta 1, catalytic subunit',
#                       'uniprot': 'P28340'},
#                      {'mygene_id': '54551',
#                       'name': 'MAGE family member L2',
#                       'uniprot': 'Q9UJ55'},
#                      {'mygene_id': '3767',
#                       'name': 'potassium inwardly rectifying channel subfamily '
#                               'J member 11',
#                       'uniprot': 'Q14654'},
#                      {'mygene_id': '79798',
#                       'name': 'armadillo repeat containing 5',
#                       'uniprot': 'Q96C12'},
#                      {'mygene_id': '107075310', 'name': 'MT-CO2 pseudogene 12'},
#                      {'mygene_id': '388015',
#                       'name': 'retrotransposon Gag like 1',
#                       'uniprot': 'A6NKG5'},
#                      {'mygene_id': '11232',
#                       'name': 'DNA polymerase gamma 2, accessory subunit',
#                       'uniprot': 'Q9UHN1'},
#                      {'mygene_id': '10560',
#                       'name': 'solute carrier family 19 member 2',
#                       'uniprot': 'O60779'},
#                      {'mygene_id': '640',
#                       'name': 'BLK proto-oncogene, Src family tyrosine kinase',
#                       'uniprot': 'P51451'},
#                      {'mygene_id': '11330',
#                       'name': 'chymotrypsin C',
#                       'uniprot': 'Q99895'},
#                      {'mygene_id': '1406',
#                       'name': 'cone-rod homeobox',
#                       'uniprot': 'O43186'},
#                      {'mygene_id': '116519',
#                       'name': 'apolipoprotein A5',
#                       'uniprot': 'Q6Q788'},
#                      {'mygene_id': '51119',
#                       'name': 'SBDS ribosome maturation factor',
#                       'uniprot': 'Q9Y3A5'},
#                      {'mygene_id': '284252',
#                       'name': 'potassium channel tetramerization domain '
#                               'containing 1',
#                       'uniprot': 'Q719H9'},
#                      {'mygene_id': '208',
#                       'name': 'AKT serine/threonine kinase 2',
#                       'uniprot': 'P31751'},
#                      {'mygene_id': '128674',
#                       'name': 'prokineticin receptor 2',
#                       'uniprot': 'Q8NFJ6'},
#                      {'mygene_id': '7490',
#                       'name': 'WT1 transcription factor',
#                       'uniprot': 'P19544'},
#                      {'mygene_id': '2099',
#                       'name': 'estrogen receptor 1',
#                       'uniprot': 'P03372'},
#                      {'mygene_id': '4567', 'name': 'tRNA-Leu'},
#                      {'mygene_id': '134218',
#                       'name': 'DnaJ heat shock protein family (Hsp40) member '
#                               'C21',
#                       'uniprot': 'Q5F1R6'},
#                      {'mygene_id': '3990',
#                       'name': 'lipase C, hepatic type',
#                       'uniprot': 'P11150'},
#                      {'mygene_id': '51300',
#                       'name': 'translocase of inner mitochondrial membrane '
#                               'domain containing 1',
#                       'uniprot': 'Q9NPL8'},
#                      {'mygene_id': '155368',
#                       'name': 'methyltransferase like 27',
#                       'uniprot': 'Q8N6F8'},
#                      {'mygene_id': '6690',
#                       'name': 'serine peptidase inhibitor Kazal type 1',
#                       'uniprot': 'P00995'},
#                      {'mygene_id': '23742',
#                       'name': 'nuclear pore associated protein 1',
#                       'uniprot': 'Q9NZP6'},
#                      {'mygene_id': '583',
#                       'name': 'Bardet-Biedl syndrome 2',
#                       'uniprot': 'Q9BXC9'},
#                      {'mygene_id': '84100',
#                       'name': 'ADP ribosylation factor like GTPase 6',
#                       'uniprot': 'Q9H0F7'},
#                      {'mygene_id': '51651',
#                       'name': 'peptidyl-tRNA hydrolase 2',
#                       'uniprot': 'Q9Y3E5'},
#                      {'mygene_id': '23503',
#                       'name': 'zinc finger FYVE-type containing 26',
#                       'uniprot': 'Q68DK2'},
#                      {'mygene_id': '1357',
#                       'name': 'carboxypeptidase A1',
#                       'uniprot': 'P15085'},
#                      {'mygene_id': '84976',
#                       'name': 'dispatched RND transporter family member 1',
#                       'uniprot': 'Q96F81'},
#                      {'mygene_id': '348',
#                       'name': 'apolipoprotein E',
#                       'uniprot': 'P02649'},
#                      {'mygene_id': '987',
#                       'name': 'LPS responsive beige-like anchor protein',
#                       'uniprot': 'P50851'},
#                      {'mygene_id': '4948',
#                       'name': 'OCA2 melanosomal transmembrane protein',
#                       'uniprot': 'Q04671'},
#                      {'mygene_id': '2979',
#                       'name': 'guanylate cyclase activator 1B',
#                       'uniprot': 'Q9UMX6'},
#                      {'mygene_id': '1258',
#                       'name': 'cyclic nucleotide gated channel subunit beta 1',
#                       'uniprot': 'Q14028'},
#                      {'mygene_id': '326',
#                       'name': 'autoimmune regulator',
#                       'uniprot': 'O43918'},
#                      {'mygene_id': '9915',
#                       'name': 'aryl hydrocarbon receptor nuclear translocator '
#                               '2',
#                       'uniprot': 'Q9HBZ2'},
#                      {'mygene_id': '8660',
#                       'name': 'insulin receptor substrate 2',
#                       'uniprot': 'Q9Y4H2'},
#                      {'mygene_id': '375298',
#                       'name': 'ceramide kinase like',
#                       'uniprot': 'Q49MI3'},
#                      {'mygene_id': '3991',
#                       'name': 'lipase E, hormone sensitive type',
#                       'uniprot': 'Q05469'},
#                      {'mygene_id': '94137',
#                       'name': 'RP1 like 1',
#                       'uniprot': 'Q8IWN7'},
#                      {'mygene_id': '493856',
#                       'name': 'CDGSH iron sulfur domain 2',
#                       'uniprot': 'Q8N5K1'},
#                      {'mygene_id': '64788',
#                       'name': 'lipase maturation factor 1',
#                       'uniprot': 'Q96S06'},
#                      {'mygene_id': '56729',
#                       'name': 'resistin',
#                       'uniprot': 'Q9HD89'},
#                      {'mygene_id': '161882',
#                       'name': 'zinc finger protein, FOG family member 1',
#                       'uniprot': 'Q8IX07'},
#                      {'mygene_id': '79797',
#                       'name': 'zinc finger protein 408',
#                       'uniprot': 'Q9H9D4'},
#                      {'mygene_id': '103',
#                       'name': 'adenosine deaminase RNA specific',
#                       'uniprot': 'P55265'},
#                      {'mygene_id': '23592',
#                       'name': 'LEM domain containing 3',
#                       'uniprot': 'Q9Y2U8'},
#                      {'mygene_id': '1280',
#                       'name': 'collagen type II alpha 1 chain',
#                       'uniprot': 'P02458'},
#                      {'mygene_id': '29078',
#                       'name': 'NADH:ubiquinone oxidoreductase complex assembly '
#                               'factor 4',
#                       'uniprot': 'Q9P032'},
#                      {'mygene_id': '762',
#                       'name': 'carbonic anhydrase 4',
#                       'uniprot': 'P22748'},
#                      {'mygene_id': '100130933',
#                       'name': 'small integral membrane protein 6',
#                       'uniprot': 'P0DI80'},
#                      {'mygene_id': '2006',
#                       'name': 'elastin',
#                       'uniprot': 'P15502'},
#                      {'mygene_id': '79650',
#                       'name': 'U6 snRNA biogenesis phosphodiesterase 1',
#                       'uniprot': 'Q9BQ65'},
#                      {'mygene_id': '4511', 'name': 'tRNA-Cys'},
#                      {'mygene_id': '5982',
#                       'name': 'replication factor C subunit 2',
#                       'uniprot': 'P35250'},
#                      {'mygene_id': '285282',
#                       'name': 'RAB, member of RAS oncogene family like 3',
#                       'uniprot': 'Q5HYI8'},
#                      {'mygene_id': '5148',
#                       'name': 'phosphodiesterase 6G',
#                       'uniprot': 'P18545'},
#                      {'mygene_id': '26060',
#                       'name': 'adaptor protein, phosphotyrosine interacting '
#                               'with PH domain and leucine zipper 1',
#                       'uniprot': 'Q9UKG1'},
#                      {'mygene_id': '3981',
#                       'name': 'DNA ligase 4',
#                       'uniprot': 'P49917'},
#                      {'mygene_id': '9479',
#                       'name': 'mitogen-activated protein kinase 8 interacting '
#                               'protein 1',
#                       'uniprot': 'Q9UQF2'},
#                      {'mygene_id': '10699',
#                       'name': 'corin, serine peptidase',
#                       'uniprot': 'Q9Y5Q5'},
#                      {'mygene_id': '57104',
#                       'name': 'patatin like phospholipase domain containing 2',
#                       'uniprot': 'Q96AD5'},
#                      {'mygene_id': '5346',
#                       'name': 'perilipin 1',
#                       'uniprot': 'O60240'},
#                      {'mygene_id': '2200',
#                       'name': 'fibrillin 1',
#                       'uniprot': 'P35555'},
#                      {'mygene_id': '7546',
#                       'name': 'Zic family member 2',
#                       'uniprot': 'O95409'},
#                      {'mygene_id': '374291',
#                       'name': 'NADH:ubiquinone oxidoreductase core subunit S7',
#                       'uniprot': 'O75251'},
#                      {'mygene_id': '8468',
#                       'name': 'FKBP prolyl isomerase family member 6 '
#                               '(inactive)',
#                       'uniprot': 'O75344'},
#                      {'mygene_id': '51218',
#                       'name': 'glutaredoxin 5',
#                       'uniprot': 'Q86SX6'},
#                      {'mygene_id': '55627',
#                       'name': 'sphingomyelin phosphodiesterase 4',
#                       'uniprot': 'Q9NXE4'},
#                      {'mygene_id': '50939',
#                       'name': 'interphotoreceptor matrix proteoglycan 2',
#                       'uniprot': 'Q9BZV3'},
#                      {'mygene_id': '64324',
#                       'name': 'nuclear receptor binding SET domain protein 1',
#                       'uniprot': 'Q96L73'},
#                      {'mygene_id': '266747',
#                       'name': 'ral guanine nucleotide dissociation stimulator '
#                               'like 4',
#                       'uniprot': 'Q8IZJ4'},
#                      {'mygene_id': '5995',
#                       'name': 'retinal G protein coupled receptor',
#                       'uniprot': 'P47804'},
#                      {'mygene_id': '2321',
#                       'name': 'fms related receptor tyrosine kinase 1',
#                       'uniprot': 'P17948'},
#                      {'mygene_id': '60509',
#                       'name': 'AGBL carboxypeptidase 5',
#                       'uniprot': 'Q8NDL9'},
#                      {'mygene_id': '6729',
#                       'name': 'signal recognition particle 54',
#                       'uniprot': 'P61011'},
#                      {'mygene_id': '92211',
#                       'name': 'cadherin related family member 1',
#                       'uniprot': 'Q96JP9'},
#                      {'mygene_id': '7050',
#                       'name': 'TGFB induced factor homeobox 1',
#                       'uniprot': 'Q15583'},
#                      {'mygene_id': '1896',
#                       'name': 'ectodysplasin A',
#                       'uniprot': 'Q92838'},
#                      {'mygene_id': '3077',
#                       'name': 'homeostatic iron regulator',
#                       'uniprot': 'Q30201'},
#                      {'mygene_id': '169792',
#                       'name': 'GLIS family zinc finger 3',
#                       'uniprot': 'Q8NEA6'},
#                      {'mygene_id': '5295',
#                       'name': 'phosphoinositide-3-kinase regulatory subunit 1',
#                       'uniprot': 'P27986'},
#                      {'mygene_id': '27086',
#                       'name': 'forkhead box P1',
#                       'uniprot': 'Q9H334'},
#                      {'mygene_id': '5144',
#                       'name': 'phosphodiesterase 4D',
#                       'uniprot': 'Q08499'},
#                      {'mygene_id': '5333',
#                       'name': 'phospholipase C delta 1',
#                       'uniprot': 'P51178'},
#                      {'mygene_id': '49855',
#                       'name': 'S-phase cyclin A associated protein in the ER',
#                       'uniprot': 'Q9BY12'},
#                      {'mygene_id': '1384',
#                       'name': 'carnitine O-acetyltransferase',
#                       'uniprot': 'P43155'},
#                      {'mygene_id': '10249',
#                       'name': 'glycine-N-acyltransferase',
#                       'uniprot': 'Q6IB77'},
#                      {'mygene_id': '847',
#                       'name': 'catalase',
#                       'uniprot': 'P04040'},
#                      {'mygene_id': '5422',
#                       'name': 'DNA polymerase alpha 1, catalytic subunit',
#                       'uniprot': 'P09884'},
#                      {'mygene_id': 'ENSG00000274497',
#                       'name': 'immunoglobulin heavy constant gamma 2 (G2m '
#                               'marker)'},
#                      {'mygene_id': '3501',
#                       'name': 'immunoglobulin heavy constant gamma 2 (G2m '
#                               'marker)'},
#                      {'mygene_id': '641',
#                       'name': 'BLM RecQ like helicase',
#                       'uniprot': 'P54132'},
#                      {'mygene_id': '23312',
#                       'name': 'Dmx like 2',
#                       'uniprot': 'Q8TDJ6'},
#                      {'mygene_id': '83737',
#                       'name': 'itchy E3 ubiquitin protein ligase',
#                       'uniprot': 'Q96J02'},
#                      {'mygene_id': '8928',
#                       'name': 'forkhead box H1',
#                       'uniprot': 'O75593'},
#                      {'mygene_id': '114049',
#                       'name': 'BUD23 rRNA methyltransferase and ribosome '
#                               'maturation factor',
#                       'uniprot': 'O43709'},
#                      {'mygene_id': 'ENSG00000270141',
#                       'name': 'telomerase RNA component'},
#                      {'mygene_id': '7012', 'name': 'telomerase RNA component'},
#                      {'mygene_id': '5192',
#                       'name': 'peroxisomal biogenesis factor 10',
#                       'uniprot': 'O60683'},
#                      {'mygene_id': '4000',
#                       'name': 'lamin A/C',
#                       'uniprot': 'P02545'},
#                      {'mygene_id': '8481',
#                       'name': 'OFD1 centriole and centriolar satellite protein',
#                       'uniprot': 'O75665'},
#                      {'mygene_id': '768206',
#                       'name': 'photoreceptor disc component',
#                       'uniprot': 'Q00LT1'},
#                      {'mygene_id': '346007',
#                       'name': 'eyes shut homolog',
#                       'uniprot': 'Q5T1H1'},
#                      {'mygene_id': '84277',
#                       'name': 'DnaJ heat shock protein family (Hsp40) member '
#                               'C30',
#                       'uniprot': 'Q96LL9'},
#                      {'mygene_id': '4519',
#                       'name': 'cytochrome b',
#                       'uniprot': 'P00156'},
#                      {'mygene_id': '50943',
#                       'name': 'forkhead box P3',
#                       'uniprot': 'Q9BZS1'},
#                      {'mygene_id': '1482',
#                       'name': 'NK2 homeobox 5',
#                       'uniprot': 'P52952'},
#                      {'mygene_id': '10594',
#                       'name': 'pre-mRNA processing factor 8',
#                       'uniprot': 'Q6P2Q9'},
#                      {'mygene_id': '5244',
#                       'name': 'ATP binding cassette subfamily B member 4',
#                       'uniprot': 'P21439'},
#                      {'mygene_id': '5573',
#                       'name': 'protein kinase cAMP-dependent type I regulatory '
#                               'subunit alpha',
#                       'uniprot': 'P10644'},
#                      {'mygene_id': '7555',
#                       'name': 'CCHC-type zinc finger nucleic acid binding '
#                               'protein',
#                       'uniprot': 'P62633'},
#                      {'mygene_id': '650',
#                       'name': 'bone morphogenetic protein 2',
#                       'uniprot': 'P12643'},
#                      {'mygene_id': '23370',
#                       'name': 'Rho/Rac guanine nucleotide exchange factor 18',
#                       'uniprot': 'Q6ZSZ5'},
#                      {'mygene_id': '57217',
#                       'name': 'tetratricopeptide repeat domain 7A',
#                       'uniprot': 'Q9ULT0'},
#                      {'mygene_id': '155382',
#                       'name': 'VPS37D subunit of ESCRT-I',
#                       'uniprot': 'Q86XT2'},
#                      {'mygene_id': '25886',
#                       'name': 'POC1 centriolar protein A',
#                       'uniprot': 'Q8NBT0'},
#                      {'mygene_id': '10644',
#                       'name': 'insulin like growth factor 2 mRNA binding '
#                               'protein 2',
#                       'uniprot': 'Q9Y6M1'},
#                      {'mygene_id': '7275',
#                       'name': 'TUB bipartite transcription factor',
#                       'uniprot': 'P50607'},
#                      {'mygene_id': '79947',
#                       'name': 'dehydrodolichyl diphosphate synthase subunit',
#                       'uniprot': 'Q86SQ9'},
#                      {'mygene_id': '23568',
#                       'name': 'ADP ribosylation factor like GTPase 2 binding '
#                               'protein',
#                       'uniprot': 'Q9Y2Y0'},
#                      {'mygene_id': '675',
#                       'name': 'BRCA2 DNA repair associated',
#                       'uniprot': 'P51587'},
#                      {'mygene_id': '3480',
#                       'name': 'insulin like growth factor 1 receptor',
#                       'uniprot': 'P08069'},
#                      {'mygene_id': '3653',
#                       'name': 'imprinted in Prader-Willi syndrome'},
#                      {'mygene_id': '5468',
#                       'name': 'peroxisome proliferator activated receptor '
#                               'gamma',
#                       'uniprot': 'P37231'},
#                      {'mygene_id': '57817',
#                       'name': 'hepcidin antimicrobial peptide',
#                       'uniprot': 'P81172'},
#                      {'mygene_id': '26160',
#                       'name': 'intraflagellar transport 172',
#                       'uniprot': 'Q9UG01'},
#                      {'mygene_id': '5158',
#                       'name': 'phosphodiesterase 6B',
#                       'uniprot': 'P35913'},
#                      {'mygene_id': '9451',
#                       'name': 'eukaryotic translation initiation factor 2 '
#                               'alpha kinase 3',
#                       'uniprot': 'Q9NZJ5'},
#                      {'mygene_id': '338433',
#                       'name': 'small nucleolar RNA, C/D box 115-1'},
#                      {'mygene_id': '80199',
#                       'name': 'fuzzy planar cell polarity protein',
#                       'uniprot': 'Q9BT04'},
#                      {'mygene_id': '5080',
#                       'name': 'paired box 6',
#                       'uniprot': 'P26367'},
#                      {'mygene_id': '2736',
#                       'name': 'GLI family zinc finger 2',
#                       'uniprot': 'P10070'},
#                      {'mygene_id': '286053',
#                       'name': 'NSE2 (MMS21) homolog, SMC5-SMC6 complex SUMO '
#                               'ligase',
#                       'uniprot': 'Q96MF7'},
#                      {'mygene_id': '3376',
#                       'name': 'isoleucyl-tRNA synthetase 1',
#                       'uniprot': 'P41252'},
#                      {'mygene_id': '26580',
#                       'name': 'BSCL2 lipid droplet biogenesis associated, '
#                               'seipin',
#                       'uniprot': 'Q96G97'},
#                      {'mygene_id': '5611',
#                       'name': 'DnaJ heat shock protein family (Hsp40) member '
#                               'C3',
#                       'uniprot': 'Q13217'},
#                      {'mygene_id': '6469',
#                       'name': 'sonic hedgehog signaling molecule',
#                       'uniprot': 'Q15465'},
#                      {'mygene_id': '4544',
#                       'name': 'melatonin receptor 1B',
#                       'uniprot': 'P49286'},
#                      {'mygene_id': '7015',
#                       'name': 'telomerase reverse transcriptase',
#                       'uniprot': 'O14746'},
#                      {'mygene_id': '3667',
#                       'name': 'insulin receptor substrate 1',
#                       'uniprot': 'P35568'},
#                      {'mygene_id': '157657',
#                       'name': 'cilia and flagella associated protein 418',
#                       'uniprot': 'Q96NL8'},
#                      {'mygene_id': '4566', 'name': 'tRNA-Lys'},
#                      {'mygene_id': '4508',
#                       'name': 'ATP synthase F0 subunit 6',
#                       'uniprot': 'P00846'},
#                      {'mygene_id': '64218',
#                       'name': 'semaphorin 4A',
#                       'uniprot': 'Q9H3S1'},
#                      {'mygene_id': '4538',
#                       'name': 'NADH dehydrogenase subunit 4',
#                       'uniprot': 'P03905'},
#                      {'mygene_id': '10535',
#                       'name': 'ribonuclease H2 subunit A',
#                       'uniprot': 'O75792'},
#                      {'mygene_id': '100033413',
#                       'name': 'small nucleolar RNA, C/D box 116-1'},
#                      {'mygene_id': '6871',
#                       'name': 'transcriptional adaptor 2A',
#                       'uniprot': 'O75478'},
#                      {'mygene_id': '51816',
#                       'name': 'adenosine deaminase 2',
#                       'uniprot': 'Q9NZK5'},
#                      {'mygene_id': '63036',
#                       'name': 'chymotrypsin like elastase 2A',
#                       'uniprot': 'P08217'},
#                      {'mygene_id': '8195',
#                       'name': 'MKKS centrosomal shuttling protein',
#                       'uniprot': 'Q9NPJ1'},
#                      {'mygene_id': '165',
#                       'name': 'AE binding protein 1',
#                       'uniprot': 'Q8IUX7'},
#                      {'mygene_id': '1056', 'name': 'carboxyl ester lipase'},
#                      {'mygene_id': '26121',
#                       'name': 'pre-mRNA processing factor 31',
#                       'uniprot': 'Q8WWY3'},
#                      {'mygene_id': '63924',
#                       'name': 'cell death inducing DFFA like effector c',
#                       'uniprot': 'Q96AQ7'},
#                      {'mygene_id': '10068',
#                       'name': 'interleukin 18 binding protein',
#                       'uniprot': 'O95998'},
#                      {'mygene_id': '7274',
# ...
#                       'name': 'cell division cycle 34',
#                       'uniprot': 'Q8CFI2'},
#                      {'mygene_id': '12368',
#                       'name': 'caspase 6',
#                       'uniprot': 'O08738'},
#                      {'mygene_id': '12051',
#                       'name': 'B cell leukemia/lymphoma 3',
#                       'uniprot': 'Q9Z2F6'},
#                      {'mygene_id': '14528',
#                       'name': 'GTP cyclohydrolase 1',
#                       'uniprot': 'Q05915'},
#                      {'mygene_id': '13714',
#                       'name': 'ELK4, member of ETS oncogene family',
#                       'uniprot': 'P41158'},
#                      {'mygene_id': '100102',
#                       'name': 'proprotein convertase subtilisin/kexin type 9',
#                       'uniprot': 'Q80W65'},
#                      {'mygene_id': '22153',
#                       'name': 'tubulin, beta 4A class IVA',
#                       'uniprot': 'Q9D6F9'},
#                      {'mygene_id': '23986',
#                       'name': 'enoyl-Coenzyme A delta isomerase 2',
#                       'uniprot': 'Q9WUR2'},
#                      {'mygene_id': '15357',
#                       'name': '3-hydroxy-3-methylglutaryl-Coenzyme A reductase',
#                       'uniprot': 'Q01237'},
#                      {'mygene_id': '108148',
#                       'name': 'polypeptide N-acetylgalactosaminyltransferase 2',
#                       'uniprot': 'Q6PB93'},
#                      {'mygene_id': '330177',
#                       'name': 'TAO kinase 3',
#                       'uniprot': 'Q8BYC6'},
#                      {'mygene_id': '223920',
#                       'name': 'sterol O-acyltransferase 2',
#                       'uniprot': 'O88908'},
#                      {'mygene_id': '110460',
#                       'name': 'acetyl-Coenzyme A acetyltransferase 2',
#                       'uniprot': 'Q8CAY6'},
#                      {'mygene_id': '67528',
#                       'name': 'nudix hydrolase 7',
#                       'uniprot': 'Q99P30'},
#                      {'mygene_id': '12608',
#                       'name': 'CCAAT/enhancer binding protein (C/EBP), beta',
#                       'uniprot': 'P28033'},
#                      {'mygene_id': '71207',
#                       'name': 'nudix hydrolase 4',
#                       'uniprot': 'Q8R2U6'},
#                      {'mygene_id': '15446',
#                       'name': 'hydroxyprostaglandin dehydrogenase 15 (NAD)',
#                       'uniprot': 'Q8VCC1'},
#                      {'mygene_id': '56812',
#                       'name': 'DnaJ heat shock protein family (Hsp40) member '
#                               'B2',
#                       'uniprot': 'Q9QYI5'},
#                      {'mygene_id': '17855',
#                       'name': 'mevalonate kinase',
#                       'uniprot': 'Q9R008'},
#                      {'mygene_id': '107829',
#                       'name': 'THO complex 5',
#                       'uniprot': 'Q8BKT7'},
#                      {'mygene_id': '27219',
#                       'name': 'serum/glucocorticoid regulated kinase 2',
#                       'uniprot': 'Q9QZS5'},
#                      {'mygene_id': '20778',
#                       'name': 'scavenger receptor class B, member 1',
#                       'uniprot': 'Q61009'},
#                      {'mygene_id': '15519',
#                       'name': 'heat shock protein 90, alpha (cytosolic), class '
#                               'A member 1',
#                       'uniprot': 'P07901'},
#                      {'mygene_id': '14585',
#                       'name': 'glial cell line derived neurotrophic factor '
#                               'family receptor alpha 1',
#                       'uniprot': 'P97785'},
#                      {'mygene_id': '21938',
#                       'name': 'tumor necrosis factor receptor superfamily, '
#                               'member 1b',
#                       'uniprot': 'P25119'},
#                      {'mygene_id': '73242',
#                       'name': 'alpha tubulin acetyltransferase 1',
#                       'uniprot': 'Q8K341'},
#                      {'mygene_id': '234724',
#                       'name': 'tyrosine aminotransferase',
#                       'uniprot': 'Q8QZR1'},
#                      {'mygene_id': '57377',
#                       'name': 'mannosyl-oligosaccharide glucosidase',
#                       'uniprot': 'Q80UM7'},
#                      {'mygene_id': '18671',
#                       'name': 'ATP-binding cassette, sub-family B (MDR/TAP), '
#                               'member 1A',
#                       'uniprot': 'P21447'},
#                      {'mygene_id': '18670',
#                       'name': 'ATP-binding cassette, sub-family B (MDR/TAP), '
#                               'member 4',
#                       'uniprot': 'P21440'},
#                      {'mygene_id': '18534',
#                       'name': 'phosphoenolpyruvate carboxykinase 1, cytosolic',
#                       'uniprot': 'Q9Z2V4'},
#                      {'mygene_id': '192156',
#                       'name': 'mevalonate (diphospho) decarboxylase',
#                       'uniprot': 'Q99JF5'},
#                      {'mygene_id': '17859',
#                       'name': 'MAX interactor 1, dimerization protein',
#                       'uniprot': 'P50540'},
#                      {'mygene_id': '107476',
#                       'name': 'acetyl-Coenzyme A carboxylase alpha',
#                       'uniprot': 'Q5SWU9'},
#                      {'mygene_id': '19651',
#                       'name': 'RB transcriptional corepressor like 2',
#                       'uniprot': 'Q64700'},
#                      {'mygene_id': '51797',
#                       'name': "cytidine 5'-triphosphate synthase",
#                       'uniprot': 'P70698'},
#                      {'mygene_id': '11855',
#                       'name': 'Rho GTPase activating protein 5',
#                       'uniprot': 'P97393'},
#                      {'mygene_id': '26412',
#                       'name': 'mitogen-activated protein kinase kinase kinase '
#                               'kinase 2',
#                       'uniprot': 'Q61161'},
#                      {'mygene_id': '103988',
#                       'name': 'glucokinase',
#                       'uniprot': 'P52792'},
#                      {'mygene_id': '50501',
#                       'name': 'prokineticin 2',
#                       'uniprot': 'Q9QXU7'},
#                      {'mygene_id': '246691',
#                       'name': 'prokineticin 1',
#                       'uniprot': 'Q14A28'},
#                      {'mygene_id': '70110',
#                       'name': 'interferon-induced protein 35',
#                       'uniprot': 'Q9D8C4'},
#                      {'mygene_id': '245839', 'name': 'granzyme N'},
#                      {'mygene_id': '14824',
#                       'name': 'granulin',
#                       'uniprot': 'P28798'},
#                      {'mygene_id': '11461',
#                       'name': 'actin, beta',
#                       'uniprot': 'P60710'},
#                      {'mygene_id': '229302',
#                       'name': 'transmembrane 4 superfamily member 4'},
#                      {'mygene_id': '210126',
#                       'name': 'LIM domain containing preferred translocation '
#                               'partner in lipoma',
#                       'uniprot': 'Q8BFW7'},
#                      {'mygene_id': '102308570',
#                       'name': 'LBH domain containing 1'},
#                      {'mygene_id': '15505',
#                       'name': 'heat shock 105kDa/110kDa protein 1',
#                       'uniprot': 'Q61699'},
#                      {'mygene_id': '75612',
#                       'name': 'glucosamine (N-acetyl)-6-sulfatase',
#                       'uniprot': 'Q8BFR4'},
#                      {'mygene_id': '19017',
#                       'name': 'peroxisome proliferative activated receptor, '
#                               'gamma, coactivator 1 alpha',
#                       'uniprot': 'O70343'},
#                      {'mygene_id': '20239',
#                       'name': 'ataxin 2',
#                       'uniprot': 'O70305'},
#                      {'mygene_id': '93736',
#                       'name': 'AF4/FMR2 family, member 4',
#                       'uniprot': 'Q9ESC8'},
#                      {'mygene_id': '14137',
#                       'name': 'farnesyl diphosphate farnesyl transferase 1',
#                       'uniprot': 'P53798'},
#                      {'mygene_id': '170826',
#                       'name': 'peroxisome proliferative activated receptor, '
#                               'gamma, coactivator 1 beta',
#                       'uniprot': 'Q8VHJ7'},
#                      {'mygene_id': '13360',
#                       'name': '7-dehydrocholesterol reductase',
#                       'uniprot': 'O88455'},
#                      {'mygene_id': '22341',
#                       'name': 'vascular endothelial growth factor C',
#                       'uniprot': 'P97953'},
#                      {'mygene_id': '19663',
#                       'name': 'RNA binding protein gene with multiple splicing',
#                       'uniprot': 'Q9WVB0'},
#                      {'mygene_id': '11989',
#                       'name': 'solute carrier family 7 (cationic amino acid '
#                               'transporter, y+ system), member 3',
#                       'uniprot': 'P70423'},
#                      {'mygene_id': '11988',
#                       'name': 'solute carrier family 7 (cationic amino acid '
#                               'transporter, y+ system), member 2',
#                       'uniprot': 'P18581'},
#                      {'mygene_id': '14377',
#                       'name': 'glucose-6-phosphatase, catalytic',
#                       'uniprot': 'P35576'},
#                      {'mygene_id': '12453',
#                       'name': 'cyclin I',
#                       'uniprot': 'Q9Z2V9'},
#                      {'mygene_id': '56878',
#                       'name': 'RNA binding motif, single stranded interacting '
#                               'protein 1',
#                       'uniprot': 'Q91W59'},
#                      {'mygene_id': '59092',
#                       'name': 'poly(rC) binding protein 4',
#                       'uniprot': 'P57724'},
#                      {'mygene_id': '13121',
#                       'name': 'cytochrome P450, family 51',
#                       'uniprot': 'Q8K0C4'},
#                      {'mygene_id': '16006',
#                       'name': 'insulin-like growth factor binding protein 1',
#                       'uniprot': 'P47876'},
#                      {'mygene_id': '20775',
#                       'name': 'squalene epoxidase',
#                       'uniprot': 'P52019'},
#                      {'mygene_id': '50798',
#                       'name': 'glucosamine '
#                               '(UDP-N-acetyl)-2-epimerase/N-acetylmannosamine '
#                               'kinase',
#                       'uniprot': 'Q91WG8'},
#                      {'mygene_id': '54720',
#                       'name': 'regulator of calcineurin 1',
#                       'uniprot': 'Q9JHG6'},
#                      {'mygene_id': '170791',
#                       'name': 'RNA binding motif protein 39',
#                       'uniprot': 'Q8VH51'},
#                      {'mygene_id': '11607',
#                       'name': 'angiotensin II receptor, type 1a',
#                       'uniprot': 'P29754'},
#                      {'mygene_id': '71795',
#                       'name': 'phosphatidylinositol transfer protein, '
#                               'cytoplasmic 1',
#                       'uniprot': 'Q8K4R4'},
#                      {'mygene_id': '29863',
#                       'name': 'phosphodiesterase 7B',
#                       'uniprot': 'Q9QXQ1'},
#                      {'mygene_id': '16337',
#                       'name': 'insulin receptor',
#                       'uniprot': 'P15208'},
#                      {'mygene_id': '66626',
#                       'name': 'cell death inducing Trp53 target 1',
#                       'uniprot': 'Q9DB75'},
#                      {'mygene_id': '245474',
#                       'name': 'dyskeratosis congenita 1, dyskerin',
#                       'uniprot': 'Q9ESX5'},
#                      {'mygene_id': '11630',
#                       'name': 'crystallin beta-gamma domain containing 1'},
#                      {'mygene_id': '16194',
#                       'name': 'interleukin 6 receptor, alpha',
#                       'uniprot': 'P22272'},
#                      {'mygene_id': '19042',
#                       'name': 'protein phosphatase 1A, magnesium dependent, '
#                               'alpha isoform',
#                       'uniprot': 'P49443'},
#                      {'mygene_id': '12894',
#                       'name': 'carnitine palmitoyltransferase 1a, liver',
#                       'uniprot': 'P97742'},
#                      {'mygene_id': '18022',
#                       'name': 'nuclear factor, erythroid derived 2',
#                       'uniprot': 'Q07279'},
#                      {'mygene_id': '15502',
#                       'name': 'DnaJ heat shock protein family (Hsp40) member '
#                               'A1',
#                       'uniprot': 'P63037'},
#                      {'mygene_id': '20979',
#                       'name': 'synaptotagmin I',
#                       'uniprot': 'P46096'},
#                      {'mygene_id': '66234',
#                       'name': 'methylsterol monoxygenase 1',
#                       'uniprot': 'Q9CRA4'},
#                      {'mygene_id': '22433',
#                       'name': 'X-box binding protein 1',
#                       'uniprot': 'O35426'},
#                      {'mygene_id': '64384',
#                       'name': 'sirtuin 3',
#                       'uniprot': 'Q8R104'},
#                      {'mygene_id': '71175',
#                       'name': 'NIPBL cohesin loading factor',
#                       'uniprot': 'Q6KCD5'},
#                      {'mygene_id': '67470',
#                       'name': 'ATP binding cassette subfamily G member 8',
#                       'uniprot': 'Q9DBM0'},
#                      {'mygene_id': '53414',
#                       'name': 'bystin-like',
#                       'uniprot': 'O54825'},
#                      {'mygene_id': '15361',
#                       'name': 'high mobility group AT-hook 1',
#                       'uniprot': 'P17095'},
#                      {'mygene_id': '16601', 'name': 'Kruppel-like factor 9'},
#                      {'mygene_id': '66603',
#                       'name': 'gem nuclear organelle associated protein 2',
#                       'uniprot': 'Q9CQQ4'},
#                      {'mygene_id': '19055',
#                       'name': 'protein phosphatase 3, catalytic subunit, alpha '
#                               'isoform',
#                       'uniprot': 'P63328'},
#                      {'mygene_id': '74754',
#                       'name': '24-dehydrocholesterol reductase',
#                       'uniprot': 'Q8VCH6'},
#                      {'mygene_id': '22210',
#                       'name': 'ubiquitin-conjugating enzyme E2B',
#                       'uniprot': 'P63147'},
#                      {'mygene_id': '233908',
#                       'name': 'fused in sarcoma',
#                       'uniprot': 'P56959'},
#                      {'mygene_id': '227613',
#                       'name': 'tubulin, beta 4B class IVB',
#                       'uniprot': 'P68372'},
#                      {'mygene_id': '13039',
#                       'name': 'cathepsin L',
#                       'uniprot': 'P06797'},
#                      {'mygene_id': '14635',
#                       'name': 'galactokinase 1',
#                       'uniprot': 'Q9R0N0'},
#                      {'mygene_id': '14933',
#                       'name': 'glycerol kinase',
#                       'uniprot': 'Q64516'}],
#            'taxid': 10090}],
#  'max_score': 38.72672,
#  'took': 4,
#  'total': 3}

# %%
## For each gene in a gene set, basic identifiers can be retrieved (such as UniProt, NCBI Gene, and others discussed in manuscript) which can be used in compatible downstream applications or to retrieve additional information from compatible resources
first_hit = data["hits"][0]
uniprot_ids = [x.get("uniprot", "") for x in first_hit["genes"]]
# do something with the list of uniprot id
pprint(uniprot_ids[:10])
# Out:
# ['Q96E93',
#  'Q8NHW3',
#  'O76024',
#  'Q96MF7',
#  'P06213',
#  'O14901',
#  'P13866',
#  'Q03135',
#  'Q12851',
#  'P35557']

# %%
## To fetch additional gene information beyond what is stored in MyGeneset.info, we can use the MyGene.info identifiers to leverage the power of MyGene.info. In this manner, we can do a post request to batch fetch the GO annotations for each gene. Other types of available gene-centric annotations and limitations when using MyGene.info can be found in the documentation for the service: https://docs.mygene.info/en/latest/doc/data.html#available-fields)
mygene_ids = [x["mygene_id"] for x in first_hit["genes"]]
querylist = ",".join(mygene_ids)
params = {"q": querylist, "fields": "name,go"}
res = requests.post("http://mygene.info/v3/query", data=params)
res = res.json()
# do something with the expanded annotations of the gene list
pprint(res[0])
# Out:
# {'_id': '10219',
#  '_score': 25.9798,
#  'go': {'BP': [{'evidence': 'TAS',
#                 'gocategory': 'BP',
#                 'id': 'GO:0006954',
#                 'pubmed': 9842918,
#                 'qualifier': 'involved_in',
#                 'term': 'inflammatory response'},
#                {'evidence': 'TAS',
#                 'gocategory': 'BP',
#                 'id': 'GO:0006968',
#                 'pubmed': 9842918,
#                 'qualifier': 'involved_in',
#                 'term': 'cellular defense response'},
#                {'evidence': 'TAS',
#                 'gocategory': 'BP',
#                 'id': 'GO:0007166',
#                 'pubmed': 9842918,
#                 'qualifier': 'involved_in',
#                 'term': 'cell surface receptor signaling pathway'},
#                {'evidence': 'IEA',
#                 'gocategory': 'BP',
#                 'id': 'GO:0045087',
#                 'qualifier': 'involved_in',
#                 'term': 'innate immune response'}],
#         'CC': [{'evidence': 'IEA',
#                 'gocategory': 'CC',
#                 'id': 'GO:0005886',
#                 'qualifier': 'located_in',
#                 'term': 'plasma membrane'},
#                {'evidence': 'TAS',
#                 'gocategory': 'CC',
#                 'id': 'GO:0016020',
#                 'pubmed': 9842918,
#                 'qualifier': 'located_in',
#                 'term': 'membrane'},
#                {'evidence': 'IDA',
#                 'gocategory': 'CC',
#                 'id': 'GO:0043231',
#                 'qualifier': 'located_in',
#                 'term': 'intracellular membrane-bounded organelle'}],
#         'MF': [{'category': 'MF',
#                 'evidence': 'IPI',
#                 'id': 'GO:0005515',
#                 'pubmed': [16189514, 25416956, 32296183, 32814053],
#                 'qualifier': 'enables',
#                 'term': 'protein binding'},
#                {'category': 'MF',
#                 'evidence': 'IEA',
#                 'id': 'GO:0030246',
#                 'qualifier': 'enables',
#                 'term': 'carbohydrate binding'},
#                {'category': 'MF',
#                 'evidence': 'TAS',
#                 'id': 'GO:0038023',
#                 'pubmed': 9765598,
#                 'qualifier': 'enables',
#                 'term': 'signaling receptor activity'}]},
#  'name': 'killer cell lectin like receptor G1',
#  'query': '10219'}
